# %% [markdown]
# # Exploratory Data Analysis - Intro to Pandas
# Welcome to the Pandas tutorial lab. This is the first notebook of the exploratory data analysis (EDA) series, where you will get your hands dirty applying the skills you have learned in the course on an actual data problem, similar to those you might encouter in real life! Here you will see and try out some basics of Pandas and get familiar with some of the useful functions that you will use across the other labs and assignments. If you already know Pandas well, feel free to skip this notebook.
#
# For the demonstration purposes you will use the [World Happiness Report](https://worldhappiness.report/) dataset. The dataset consists of 2199 rows, where each row contains various hapiness-related metrics for a certain country in a given year. Right now you'll just use this dataset to understand some fundamental operations in Pandas. You will see this dataset again later in week 3, where you will dig deeper into the data and explore relationships to better understand which factors seem to best predict happiness.
#
# This notebook is not a comprehensive guide to Pandas, but rather shows and explains the functions you will use through this course. For a more comprehensive guide on Pandas, please see the [official tutorial](https://pandas.pydata.org/pandas-docs/stable/user_guide/10min.html) or check the documentation.

# %% [markdown]
# # 1. Importing the Libraries
# The most important library you will need in this notebook is - you guessed it - `Pandas`. You will also use the `Seaborn` library for plotting the data. To import the libraries run the cell below.

# %%
# Import the Pandas library
import pandas as pd

# Import the Seaborn library for plotting
#!pip install seaborn
import seaborn as sns

# %% [markdown]
# # 2. Importing the Data
# Now that you have the pandas library imported, you'll need to load your dataset. The dataset you will use is saved as a `.csv` file and all you need to do to load is call the function `pd.read_csv(filename)`. If you have your data in another format, there exists a variety of functions to load it, you can check the documentation [here](https://pandas.pydata.org/pandas-docs/stable/reference/io.html).
# When you load the dataset, it will be stored as a `DataFrame` type (see the documentation [here](https://pandas.pydata.org/pandas-docs/stable/reference/frame.html)). This is the most commonly used Pandas datastructure that you will use throughout this and other notebooks.

# %%
# Load the dataset and save it to the df variable
df = pd.read_csv("dataset/world_happiness.csv")
display(df)
# Out:
#      Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 0     Afghanistan  2008        3.724               7.350           0.451
# 1     Afghanistan  2009        4.402               7.509           0.552
# 2     Afghanistan  2010        4.758               7.614           0.539
# 3     Afghanistan  2011        3.832               7.581           0.521
# 4     Afghanistan  2012        3.783               7.661           0.521
# ...           ...   ...          ...                 ...             ...
# 2194     Zimbabwe  2018        3.616               7.783           0.775
# 2195     Zimbabwe  2019        2.694               7.698           0.759
# 2196     Zimbabwe  2020        3.160               7.596           0.717
# 2197     Zimbabwe  2021        3.155               7.657           0.685
# 2198     Zimbabwe  2022        3.296               7.670           0.666
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# 0                               50.500                         0.718
# 1                               50.800                         0.679
# 2                               51.100                         0.600
# 3                               51.400                         0.496
# 4                               51.700                         0.531
# ...                                ...                           ...
# 2194                            52.625                         0.763
# 2195                            53.100                         0.632
# 2196                            53.575                         0.643
# 2197                            54.050                         0.668
# 2198                            54.525                         0.652
#
#       Generosity  Perceptions of corruption  Positive affect  Negative affect
# 0          0.168                      0.882            0.414            0.258
# 1          0.191                      0.850            0.481            0.237
# 2          0.121                      0.707            0.517            0.275
# 3          0.164                      0.731            0.480            0.267
# 4          0.238                      0.776            0.614            0.268
# ...          ...                        ...              ...              ...
# 2194      -0.051                      0.844            0.658            0.212
# 2195      -0.047                      0.831            0.658            0.235
# 2196       0.006                      0.789            0.661            0.346
# 2197      -0.076                      0.757            0.610            0.242
# 2198      -0.070                      0.753            0.641            0.191
#
# [2199 rows x 11 columns]

# %% [markdown]
# # 3. Basic Operations With a Dataframe
#
# ## 3.1 View the Dataframe
# You can use `DataFrame.head()` and `DataFrame.tail()` to view the first or last rows of the frame respectively. By default it will show you five rows, but you can specify the number of rows you want to see as a parameter. Technically, neither of the functions actually display anything, but just return a new dataframe. The dataframe is displayed because Jupyter notebooks show the output of the last row in the cell. You can also display the contents of your dataframe by simply writing `df`. If your dataframe is too long, it will then display only the first and the last few rows.
#
# Note that all of this only works if you use it in the last line of code in the cell, because the cells automatically display the output of the last line. If you want to see more than one dataframe by running a single cell or if you want to perform some other tasks after displaying the dataframe, then you better encapsulate it with `print()` or `display()`. `display()` function will print the dataframe, but with the same format as just calling `df`, whereas `print()` will print as plain text.
#
# Try commenting and uncommenting lines below, to see how this plays out. Try different combiations of rows.

# %%
# This line will display the first few rows of the dataframe if there are no lines of code after.
df.head()

# Try uncommenting different combinations of the lines below.
# print("Cats are cool.")
# print(df.head())
# print(df)
# print("Some more text about cats being cool.")
# display(df)
# Out:
#   Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 0  Afghanistan  2008        3.724               7.350           0.451
# 1  Afghanistan  2009        4.402               7.509           0.552
# 2  Afghanistan  2010        4.758               7.614           0.539
# 3  Afghanistan  2011        3.832               7.581           0.521
# 4  Afghanistan  2012        3.783               7.661           0.521
#
#    Healthy life expectancy at birth  Freedom to make life choices  Generosity  \
# 0                              50.5                         0.718       0.168
# 1                              50.8                         0.679       0.191
# 2                              51.1                         0.600       0.121
# 3                              51.4                         0.496       0.164
# 4                              51.7                         0.531       0.238
#
#    Perceptions of corruption  Positive affect  Negative affect
# 0                      0.882            0.414            0.258
# 1                      0.850            0.481            0.237
# 2                      0.707            0.517            0.275
# 3                      0.731            0.480            0.267
# 4                      0.776            0.614            0.268

# %% [markdown]
# Now display the last few rows of the dataframe. Pay attention to the additional parameter that specifies the number of rows.

# %%
# This line will display only the last two rows of the dataframe.
df.tail(2)
# Out:
#      Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 2197     Zimbabwe  2021        3.155               7.657           0.685
# 2198     Zimbabwe  2022        3.296               7.670           0.666
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# 2197                            54.050                         0.668
# 2198                            54.525                         0.652
#
#       Generosity  Perceptions of corruption  Positive affect  Negative affect
# 2197      -0.076                      0.757            0.610            0.242
# 2198      -0.070                      0.753            0.641            0.191

# %% [markdown]
# ## 3.2 Index and Column Names
# In the `DataFrame`, the data is stored in a two dimensional grid (rows and columns). The rows are indexed and the columns are named. To see the index or the column names, you can use `DataFrame.index` or `DataFrame.columns` respectively.

# %%
df.index
# Out:
# RangeIndex(start=0, stop=2199, step=1)

# %% [markdown]
# As you can see, the index is a range of numbers between 0 (inclusive) and 2199 (not inclusive).
#
# Run the cell below to see the column names.

# %%
df.columns
# Out:
# Index(['Country name', 'year', 'Life Ladder', 'Log GDP per capita',
#        'Social support', 'Healthy life expectancy at birth',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'Positive affect', 'Negative affect'],
#       dtype='object')

# %% [markdown]
# The column names are saved as strings. As you can see, they can include spaces. This can lead to difficulties when accessing the columns (you will see this very soon), so it is a good idea to rename them to get rid of the spaces. A common practice is to replace them with underscores. To rename the columns, you can use `DataFrame.rename()` and pass the columns you want to rename in a dictionary.
#
# In the next example, you will see how you can automatically replace all spaces with underscores

# %%
# A dictionary mapping old column names to new column names. In addition to replacing spaces
# with underscores, you will make all of the text lowercase.
columns_to_rename = {i: "_".join(i.split(" ")).lower() for i in df.columns}
# Note that this dictionary is created automatically from the column names.
# You can also create it by hand and rename only the columns you want to rename
# For example, see the commented line below:
# columns_to_rename = {"Country name": "country_name", "Life Ladder": "life_ladder"}

# Rename the columns
df = df.rename(columns=columns_to_rename)
# Display the new dataframe
df.head()
# Out:
#   country_name  year  life_ladder  log_gdp_per_capita  social_support  \
# 0  Afghanistan  2008        3.724               7.350           0.451
# 1  Afghanistan  2009        4.402               7.509           0.552
# 2  Afghanistan  2010        4.758               7.614           0.539
# 3  Afghanistan  2011        3.832               7.581           0.521
# 4  Afghanistan  2012        3.783               7.661           0.521
#
#    healthy_life_expectancy_at_birth  freedom_to_make_life_choices  generosity  \
# 0                              50.5                         0.718       0.168
# 1                              50.8                         0.679       0.191
# 2                              51.1                         0.600       0.121
# 3                              51.4                         0.496       0.164
# 4                              51.7                         0.531       0.238
#
#    perceptions_of_corruption  positive_affect  negative_affect
# 0                      0.882            0.414            0.258
# 1                      0.850            0.481            0.237
# 2                      0.707            0.517            0.275
# 3                      0.731            0.480            0.267
# 4                      0.776            0.614            0.268

# %% [markdown]
# ## 3.3 Data Types
# One cool thing about the DataFrame type is that the columns of the resulting DataFrame can have different `dtypes`. This is something you simply can not do with a Numpy array. You can look at them and if needed to you can change them.

# %%
df.dtypes
# Out:
# country_name                         object
# year                                  int64
# life_ladder                         float64
# log_gdp_per_capita                  float64
# social_support                      float64
# healthy_life_expectancy_at_birth    float64
# freedom_to_make_life_choices        float64
# generosity                          float64
# perceptions_of_corruption           float64
# positive_affect                     float64
# negative_affect                     float64
# dtype: object

# %% [markdown]
# You can see that the columns above are of different types and if you compare it to how the data actually looks like, it seems that the types are correct. Sometimes if your data is incorrectly formatted, the imported types will be wrong. In this case you will want to change the types of the columns manually before proceeding. Check the code below on how you can do that. Note that nothing will change after running the code below, as the data is already of correct types.

# %%
# List all of the columns that should be floats
float_columns = [i for i in df.columns if i not in ["country_name", "year"]]
# Change the type of all float columns to float
df = df.astype({i: float for i in float_columns})
# Show the types of all columns
df.dtypes
# Out:
# country_name                         object
# year                                  int64
# life_ladder                         float64
# log_gdp_per_capita                  float64
# social_support                      float64
# healthy_life_expectancy_at_birth    float64
# freedom_to_make_life_choices        float64
# generosity                          float64
# perceptions_of_corruption           float64
# positive_affect                     float64
# negative_affect                     float64
# dtype: object

# %% [markdown]
# The `df.info()` provides some additional information. In addition to data types it also tells you the number of non-null values per column.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2199 entries, 0 to 2198
# Data columns (total 11 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   country_name                      2199 non-null   object
#  1   year                              2199 non-null   int64
#  2   life_ladder                       2199 non-null   float64
#  3   log_gdp_per_capita                2179 non-null   float64
#  4   social_support                    2186 non-null   float64
#  5   healthy_life_expectancy_at_birth  2145 non-null   float64
#  6   freedom_to_make_life_choices      2166 non-null   float64
#  7   generosity                        2126 non-null   float64
#  8   perceptions_of_corruption         2083 non-null   float64
#  9   positive_affect                   2175 non-null   float64
#  10  negative_affect                   2183 non-null   float64
# dtypes: float64(9), int64(1), object(1)
# memory usage: 189.1+ KB

# %% [markdown]
# ## 3.4 Selecting Columns
# One way of selecting a single column is to use `DataFrame.column_name`. Here you can see why it was a good idea that you renamed the columns to not include any whitespaces. This returns a Pandas `Series`, which is a different datatype from a `DataFrame`. You will see how to return a `DataFrame` a bit later.

# %%
# Select the life_ladder column and store it in x
x = df.life_ladder

print(f"type(x):\n {type(x)}\n")
print(f"x:\n{x}")
# Out:
# type(x):
#  <class 'pandas.core.series.Series'>
#
# x:
# 0       3.724
# 1       4.402
# 2       4.758
# 3       3.832
# 4       3.783
#         ...
# 2194    3.616
# 2195    2.694
# 2196    3.160
# 2197    3.155
# 2198    3.296
# Name: life_ladder, Length: 2199, dtype: float64

# %% [markdown]
# Another way to do this is to use square brackets and the name of the column in quortes, much as you would do when accessing an entry in a dictionary. As with dictionaries, you can use double quotes or simple quotes.

# %%
x = df["life_ladder"]

print(f"type(x):\n {type(x)}\n")
print(f"x:\n{x}")
# Out:
# type(x):
#  <class 'pandas.core.series.Series'>
#
# x:
# 0       3.724
# 1       4.402
# 2       4.758
# 3       3.832
# 4       3.783
#         ...
# 2194    3.616
# 2195    2.694
# 2196    3.160
# 2197    3.155
# 2198    3.296
# Name: life_ladder, Length: 2199, dtype: float64

# %% [markdown]
# Passing a list of labels rather than a single label selects the columns and returns a DataFrame (rather than a Series), with only the selected columns. You can use it to select one or more columns.

# %%
# x = df[["life_ladder"]]
x = df[["life_ladder", "year"]]

print(f"type(x):\n {type(x)}\n")
print(f"x:\n{x}")
# Out:
# type(x):
#  <class 'pandas.core.frame.DataFrame'>
#
# x:
#       life_ladder  year
# 0           3.724  2008
# 1           4.402  2009
# 2           4.758  2010
# 3           3.832  2011
# 4           3.783  2012
# ...           ...   ...
# 2194        3.616  2018
# 2195        2.694  2019
# 2196        3.160  2020
# 2197        3.155  2021
# 2198        3.296  2022
#
# [2199 rows x 2 columns]

# %% [markdown]
# ## 3.5 Selecting Rows
# Passing a slice `:` selects matching rows and returns a DataFrame with all columns in your original dataframe.

# %%
df[2:5]
# Out:
#   country_name  year  life_ladder  log_gdp_per_capita  social_support  \
# 2  Afghanistan  2010        4.758               7.614           0.539
# 3  Afghanistan  2011        3.832               7.581           0.521
# 4  Afghanistan  2012        3.783               7.661           0.521
#
#    healthy_life_expectancy_at_birth  freedom_to_make_life_choices  generosity  \
# 2                              51.1                         0.600       0.121
# 3                              51.4                         0.496       0.164
# 4                              51.7                         0.531       0.238
#
#    perceptions_of_corruption  positive_affect  negative_affect
# 2                      0.707            0.517            0.275
# 3                      0.731            0.480            0.267
# 4                      0.776            0.614            0.268

# %%
df[:4]
# Out:
#   country_name  year  life_ladder  log_gdp_per_capita  social_support  \
# 0  Afghanistan  2008        3.724               7.350           0.451
# 1  Afghanistan  2009        4.402               7.509           0.552
# 2  Afghanistan  2010        4.758               7.614           0.539
# 3  Afghanistan  2011        3.832               7.581           0.521
#
#    healthy_life_expectancy_at_birth  freedom_to_make_life_choices  generosity  \
# 0                              50.5                         0.718       0.168
# 1                              50.8                         0.679       0.191
# 2                              51.1                         0.600       0.121
# 3                              51.4                         0.496       0.164
#
#    perceptions_of_corruption  positive_affect  negative_affect
# 0                      0.882            0.414            0.258
# 1                      0.850            0.481            0.237
# 2                      0.707            0.517            0.275
# 3                      0.731            0.480            0.267

# %% [markdown]
# ## 3.6 Iterating Over Rows
# If you want to iterate over the rows, you can use the `.iterrows()` method. For each row it yields a (index, row) tuple, where the row is a `Series` object containing the data. Note that this does not preserve the data types (dtypes) across the rows (dtypes are preserved across columns for DataFrames).

# %%
index, row = next(df.iterrows())
row
# Out:
# country_name                        Afghanistan
# year                                       2008
# life_ladder                               3.724
# log_gdp_per_capita                         7.35
# social_support                            0.451
# healthy_life_expectancy_at_birth           50.5
# freedom_to_make_life_choices              0.718
# generosity                                0.168
# perceptions_of_corruption                 0.882
# positive_affect                           0.414
# negative_affect                           0.258
# Name: 0, dtype: object

# %%
for index, row in df.iterrows():
    # Access each row as a Series using 'row'
    print(index, row["country_name"])
# Out:
# 0 Afghanistan
# 1 Afghanistan
# 2 Afghanistan
# 3 Afghanistan
# 4 Afghanistan
# 5 Afghanistan
# 6 Afghanistan
# 7 Afghanistan
# 8 Afghanistan
# 9 Afghanistan
# 10 Afghanistan
# 11 Afghanistan
# 12 Afghanistan
# 13 Afghanistan
# 14 Albania
# 15 Albania
# 16 Albania
# 17 Albania
# 18 Albania
# 19 Albania
# 20 Albania
# 21 Albania
# 22 Albania
# 23 Albania
# 24 Albania
# 25 Albania
# 26 Albania
# 27 Albania
# 28 Albania
# 29 Algeria
# 30 Algeria
# 31 Algeria
# 32 Algeria
# 33 Algeria
# 34 Algeria
# 35 Algeria
# 36 Algeria
# 37 Algeria
# 38 Algeria
# 39 Angola
# 40 Angola
# 41 Angola
# 42 Angola
# 43 Argentina
# 44 Argentina
# 45 Argentina
# 46 Argentina
# 47 Argentina
# 48 Argentina
# 49 Argentina
# 50 Argentina
# 51 Argentina
# 52 Argentina
# 53 Argentina
# 54 Argentina
# 55 Argentina
# 56 Argentina
# 57 Argentina
# 58 Argentina
# 59 Argentina
# 60 Armenia
# 61 Armenia
# 62 Armenia
# 63 Armenia
# 64 Armenia
# 65 Armenia
# 66 Armenia
# 67 Armenia
# 68 Armenia
# 69 Armenia
# 70 Armenia
# 71 Armenia
# 72 Armenia
# 73 Armenia
# 74 Armenia
# 75 Armenia
# 76 Australia
# 77 Australia
# 78 Australia
# 79 Australia
# 80 Australia
# 81 Australia
# 82 Australia
# 83 Australia
# 84 Australia
# 85 Australia
# 86 Australia
# 87 Australia
# 88 Australia
# 89 Australia
# 90 Australia
# 91 Australia
# 92 Austria
# 93 Austria
# 94 Austria
# 95 Austria
# 96 Austria
# 97 Austria
# 98 Austria
# 99 Austria
# 100 Austria
# 101 Austria
# 102 Austria
# 103 Austria
# 104 Austria
# 105 Austria
# 106 Austria
# 107 Azerbaijan
# 108 Azerbaijan
# 109 Azerbaijan
# 110 Azerbaijan
# 111 Azerbaijan
# 112 Azerbaijan
# 113 Azerbaijan
# 114 Azerbaijan
# 115 Azerbaijan
# 116 Azerbaijan
# 117 Azerbaijan
# 118 Azerbaijan
# 119 Azerbaijan
# 120 Azerbaijan
# 121 Bahrain
# 122 Bahrain
# 123 Bahrain
# 124 Bahrain
# 125 Bahrain
# 126 Bahrain
# 127 Bahrain
# 128 Bahrain
# 129 Bahrain
# 130 Bahrain
# 131 Bahrain
# 132 Bangladesh
# 133 Bangladesh
# 134 Bangladesh
# 135 Bangladesh
# 136 Bangladesh
# 137 Bangladesh
# 138 Bangladesh
# 139 Bangladesh
# 140 Bangladesh
# 141 Bangladesh
# 142 Bangladesh
# 143 Bangladesh
# 144 Bangladesh
# 145 Bangladesh
# 146 Bangladesh
# 147 Bangladesh
# 148 Bangladesh
# 149 Belarus
# 150 Belarus
# 151 Belarus
# 152 Belarus
# 153 Belarus
# 154 Belarus
# 155 Belarus
# 156 Belarus
# 157 Belarus
# 158 Belarus
# 159 Belarus
# 160 Belarus
# 161 Belarus
# 162 Belarus
# 163 Belgium
# 164 Belgium
# 165 Belgium
# 166 Belgium
# 167 Belgium
# 168 Belgium
# 169 Belgium
# 170 Belgium
# 171 Belgium
# 172 Belgium
# 173 Belgium
# 174 Belgium
# 175 Belgium
# 176 Belgium
# 177 Belgium
# 178 Belgium
# 179 Belize
# 180 Belize
# 181 Benin
# 182 Benin
# 183 Benin
# 184 Benin
# 185 Benin
# 186 Benin
# 187 Benin
# 188 Benin
# 189 Benin
# 190 Benin
# 191 Benin
# 192 Benin
# 193 Benin
# 194 Benin
# 195 Bhutan
# 196 Bhutan
# 197 Bhutan
# 198 Bolivia
# 199 Bolivia
# 200 Bolivia
# 201 Bolivia
# 202 Bolivia
# 203 Bolivia
# 204 Bolivia
# 205 Bolivia
# 206 Bolivia
# 207 Bolivia
# 208 Bolivia
# 209 Bolivia
# 210 Bolivia
# 211 Bolivia
# 212 Bolivia
# 213 Bolivia
# 214 Bolivia
# 215 Bosnia and Herzegovina
# 216 Bosnia and Herzegovina
# 217 Bosnia and Herzegovina
# 218 Bosnia and Herzegovina
# 219 Bosnia and Herzegovina
# 220 Bosnia and Herzegovina
# 221 Bosnia and Herzegovina
# 222 Bosnia and Herzegovina
# 223 Bosnia and Herzegovina
# 224 Bosnia and Herzegovina
# 225 Bosnia and Herzegovina
# 226 Bosnia and Herzegovina
# 227 Bosnia and Herzegovina
# 228 Bosnia and Herzegovina
# 229 Botswana
# 230 Botswana
# 231 Botswana
# 232 Botswana
# 233 Botswana
# 234 Botswana
# 235 Botswana
# 236 Botswana
# 237 Botswana
# 238 Botswana
# 239 Botswana
# 240 Botswana
# 241 Botswana
# 242 Brazil
# 243 Brazil
# 244 Brazil
# 245 Brazil
# 246 Brazil
# 247 Brazil
# 248 Brazil
# 249 Brazil
# 250 Brazil
# 251 Brazil
# 252 Brazil
# 253 Brazil
# 254 Brazil
# 255 Brazil
# 256 Brazil
# 257 Brazil
# 258 Brazil
# 259 Bulgaria
# 260 Bulgaria
# 261 Bulgaria
# 262 Bulgaria
# 263 Bulgaria
# 264 Bulgaria
# 265 Bulgaria
# 266 Bulgaria
# 267 Bulgaria
# 268 Bulgaria
# 269 Bulgaria
# 270 Bulgaria
# 271 Bulgaria
# 272 Bulgaria
# 273 Burkina Faso
# 274 Burkina Faso
# 275 Burkina Faso
# 276 Burkina Faso
# 277 Burkina Faso
# 278 Burkina Faso
# 279 Burkina Faso
# 280 Burkina Faso
# 281 Burkina Faso
# 282 Burkina Faso
# 283 Burkina Faso
# 284 Burkina Faso
# 285 Burkina Faso
# 286 Burkina Faso
# 287 Burkina Faso
# 288 Burundi
# 289 Burundi
# 290 Burundi
# 291 Burundi
# 292 Burundi
# 293 Cambodia
# 294 Cambodia
# 295 Cambodia
# 296 Cambodia
# 297 Cambodia
# 298 Cambodia
# 299 Cambodia
# 300 Cambodia
# 301 Cambodia
# 302 Cambodia
# 303 Cambodia
# 304 Cambodia
# 305 Cambodia
# 306 Cambodia
# 307 Cambodia
# 308 Cambodia
# 309 Cambodia
# 310 Cameroon
# 311 Cameroon
# 312 Cameroon
# 313 Cameroon
# 314 Cameroon
# 315 Cameroon
# 316 Cameroon
# 317 Cameroon
# 318 Cameroon
# 319 Cameroon
# 320 Cameroon
# 321 Cameroon
# 322 Cameroon
# 323 Cameroon
# 324 Cameroon
# 325 Cameroon
# 326 Cameroon
# 327 Canada
# 328 Canada
# 329 Canada
# 330 Canada
# 331 Canada
# 332 Canada
# 333 Canada
# 334 Canada
# 335 Canada
# 336 Canada
# 337 Canada
# 338 Canada
# 339 Canada
# 340 Canada
# 341 Canada
# 342 Canada
# 343 Canada
# 344 Central African Republic
# 345 Central African Republic
# 346 Central African Republic
# 347 Central African Republic
# 348 Central African Republic
# 349 Chad
# 350 Chad
# 351 Chad
# 352 Chad
# 353 Chad
# 354 Chad
# 355 Chad
# 356 Chad
# 357 Chad
# 358 Chad
# 359 Chad
# 360 Chad
# 361 Chad
# 362 Chad
# 363 Chad
# 364 Chile
# 365 Chile
# 366 Chile
# 367 Chile
# 368 Chile
# 369 Chile
# 370 Chile
# 371 Chile
# 372 Chile
# 373 Chile
# 374 Chile
# 375 Chile
# 376 Chile
# 377 Chile
# 378 Chile
# 379 Chile
# 380 Chile
# 381 China
# 382 China
# 383 China
# 384 China
# 385 China
# 386 China
# 387 China
# 388 China
# 389 China
# 390 China
# 391 China
# 392 China
# 393 China
# 394 China
# 395 China
# 396 China
# 397 Colombia
# 398 Colombia
# 399 Colombia
# 400 Colombia
# 401 Colombia
# 402 Colombia
# 403 Colombia
# 404 Colombia
# 405 Colombia
# 406 Colombia
# 407 Colombia
# 408 Colombia
# 409 Colombia
# 410 Colombia
# 411 Colombia
# 412 Colombia
# 413 Colombia
# 414 Comoros
# 415 Comoros
# 416 Comoros
# 417 Comoros
# 418 Comoros
# 419 Comoros
# 420 Comoros
# 421 Congo (Brazzaville)
# 422 Congo (Brazzaville)
# 423 Congo (Brazzaville)
# 424 Congo (Brazzaville)
# 425 Congo (Brazzaville)
# 426 Congo (Brazzaville)
# 427 Congo (Brazzaville)
# 428 Congo (Brazzaville)
# 429 Congo (Brazzaville)
# 430 Congo (Brazzaville)
# 431 Congo (Brazzaville)
# 432 Congo (Brazzaville)
# 433 Congo (Brazzaville)
# 434 Congo (Kinshasa)
# 435 Congo (Kinshasa)
# 436 Congo (Kinshasa)
# 437 Congo (Kinshasa)
# 438 Congo (Kinshasa)
# 439 Congo (Kinshasa)
# 440 Congo (Kinshasa)
# 441 Congo (Kinshasa)
# 442 Congo (Kinshasa)
# 443 Costa Rica
# 444 Costa Rica
# 445 Costa Rica
# 446 Costa Rica
# 447 Costa Rica
# 448 Costa Rica
# 449 Costa Rica
# 450 Costa Rica
# 451 Costa Rica
# 452 Costa Rica
# 453 Costa Rica
# 454 Costa Rica
# 455 Costa Rica
# 456 Costa Rica
# 457 Costa Rica
# 458 Costa Rica
# 459 Costa Rica
# 460 Croatia
# 461 Croatia
# 462 Croatia
# 463 Croatia
# 464 Croatia
# 465 Croatia
# 466 Croatia
# 467 Croatia
# 468 Croatia
# 469 Croatia
# 470 Croatia
# 471 Croatia
# 472 Croatia
# 473 Croatia
# 474 Croatia
# 475 Cuba
# 476 Cyprus
# 477 Cyprus
# 478 Cyprus
# 479 Cyprus
# 480 Cyprus
# 481 Cyprus
# 482 Cyprus
# 483 Cyprus
# 484 Cyprus
# 485 Cyprus
# 486 Cyprus
# 487 Cyprus
# 488 Cyprus
# 489 Cyprus
# 490 Cyprus
# 491 Czechia
# 492 Czechia
# 493 Czechia
# 494 Czechia
# 495 Czechia
# 496 Czechia
# 497 Czechia
# 498 Czechia
# 499 Czechia
# 500 Czechia
# 501 Czechia
# 502 Czechia
# 503 Czechia
# 504 Czechia
# 505 Denmark
# 506 Denmark
# 507 Denmark
# 508 Denmark
# 509 Denmark
# 510 Denmark
# 511 Denmark
# 512 Denmark
# 513 Denmark
# 514 Denmark
# 515 Denmark
# 516 Denmark
# 517 Denmark
# 518 Denmark
# 519 Denmark
# 520 Denmark
# 521 Denmark
# 522 Djibouti
# 523 Djibouti
# 524 Djibouti
# 525 Djibouti
# 526 Dominican Republic
# 527 Dominican Republic
# 528 Dominican Republic
# 529 Dominican Republic
# 530 Dominican Republic
# 531 Dominican Republic
# 532 Dominican Republic
# 533 Dominican Republic
# 534 Dominican Republic
# 535 Dominican Republic
# 536 Dominican Republic
# 537 Dominican Republic
# 538 Dominican Republic
# 539 Dominican Republic
# 540 Dominican Republic
# 541 Dominican Republic
# 542 Dominican Republic
# 543 Ecuador
# 544 Ecuador
# 545 Ecuador
# 546 Ecuador
# 547 Ecuador
# 548 Ecuador
# 549 Ecuador
# 550 Ecuador
# 551 Ecuador
# 552 Ecuador
# 553 Ecuador
# 554 Ecuador
# 555 Ecuador
# 556 Ecuador
# 557 Ecuador
# 558 Ecuador
# 559 Ecuador
# 560 Egypt
# 561 Egypt
# 562 Egypt
# 563 Egypt
# 564 Egypt
# 565 Egypt
# 566 Egypt
# 567 Egypt
# 568 Egypt
# 569 Egypt
# 570 Egypt
# 571 Egypt
# 572 Egypt
# 573 Egypt
# 574 Egypt
# 575 Egypt
# 576 Egypt
# 577 El Salvador
# 578 El Salvador
# 579 El Salvador
# 580 El Salvador
# 581 El Salvador
# 582 El Salvador
# 583 El Salvador
# 584 El Salvador
# 585 El Salvador
# 586 El Salvador
# 587 El Salvador
# 588 El Salvador
# 589 El Salvador
# 590 El Salvador
# 591 El Salvador
# 592 El Salvador
# 593 El Salvador
# 594 Estonia
# 595 Estonia
# 596 Estonia
# 597 Estonia
# 598 Estonia
# 599 Estonia
# 600 Estonia
# 601 Estonia
# 602 Estonia
# 603 Estonia
# 604 Estonia
# 605 Estonia
# 606 Estonia
# 607 Estonia
# 608 Estonia
# 609 Estonia
# 610 Eswatini
# 611 Eswatini
# 612 Eswatini
# 613 Ethiopia
# 614 Ethiopia
# 615 Ethiopia
# 616 Ethiopia
# 617 Ethiopia
# 618 Ethiopia
# 619 Ethiopia
# 620 Ethiopia
# 621 Ethiopia
# 622 Ethiopia
# 623 Finland
# 624 Finland
# 625 Finland
# 626 Finland
# 627 Finland
# 628 Finland
# 629 Finland
# 630 Finland
# 631 Finland
# 632 Finland
# 633 Finland
# 634 Finland
# 635 Finland
# 636 Finland
# 637 Finland
# 638 France
# 639 France
# 640 France
# 641 France
# 642 France
# 643 France
# 644 France
# 645 France
# 646 France
# 647 France
# 648 France
# 649 France
# 650 France
# 651 France
# 652 France
# 653 France
# 654 France
# 655 Gabon
# 656 Gabon
# 657 Gabon
# 658 Gabon
# 659 Gabon
# 660 Gabon
# 661 Gabon
# 662 Gabon
# 663 Gabon
# 664 Gabon
# 665 Gabon
# 666 Gabon
# 667 Gambia
# 668 Gambia
# 669 Gambia
# 670 Gambia
# 671 Georgia
# 672 Georgia
# 673 Georgia
# 674 Georgia
# 675 Georgia
# 676 Georgia
# 677 Georgia
# 678 Georgia
# 679 Georgia
# 680 Georgia
# 681 Georgia
# 682 Georgia
# 683 Georgia
# 684 Georgia
# 685 Georgia
# 686 Georgia
# 687 Georgia
# 688 Germany
# 689 Germany
# 690 Germany
# 691 Germany
# 692 Germany
# 693 Germany
# 694 Germany
# 695 Germany
# 696 Germany
# 697 Germany
# 698 Germany
# 699 Germany
# 700 Germany
# 701 Germany
# 702 Germany
# 703 Germany
# 704 Germany
# 705 Ghana
# 706 Ghana
# 707 Ghana
# 708 Ghana
# 709 Ghana
# 710 Ghana
# 711 Ghana
# 712 Ghana
# 713 Ghana
# 714 Ghana
# 715 Ghana
# 716 Ghana
# 717 Ghana
# 718 Ghana
# 719 Ghana
# 720 Ghana
# 721 Ghana
# 722 Greece
# 723 Greece
# 724 Greece
# 725 Greece
# 726 Greece
# 727 Greece
# 728 Greece
# 729 Greece
# 730 Greece
# 731 Greece
# 732 Greece
# 733 Greece
# 734 Greece
# 735 Greece
# 736 Greece
# 737 Greece
# 738 Guatemala
# 739 Guatemala
# 740 Guatemala
# 741 Guatemala
# 742 Guatemala
# 743 Guatemala
# 744 Guatemala
# 745 Guatemala
# 746 Guatemala
# 747 Guatemala
# 748 Guatemala
# 749 Guatemala
# 750 Guatemala
# 751 Guatemala
# 752 Guatemala
# 753 Guinea
# 754 Guinea
# 755 Guinea
# 756 Guinea
# 757 Guinea
# 758 Guinea
# 759 Guinea
# 760 Guinea
# 761 Guinea
# 762 Guinea
# 763 Guinea
# 764 Guinea
# 765 Guyana
# 766 Haiti
# 767 Haiti
# 768 Haiti
# 769 Haiti
# 770 Haiti
# 771 Haiti
# 772 Haiti
# 773 Haiti
# 774 Haiti
# 775 Haiti
# 776 Haiti
# 777 Honduras
# 778 Honduras
# 779 Honduras
# 780 Honduras
# 781 Honduras
# 782 Honduras
# 783 Honduras
# 784 Honduras
# 785 Honduras
# 786 Honduras
# 787 Honduras
# 788 Honduras
# 789 Honduras
# 790 Honduras
# 791 Honduras
# 792 Honduras
# 793 Hong Kong S.A.R. of China
# 794 Hong Kong S.A.R. of China
# 795 Hong Kong S.A.R. of China
# 796 Hong Kong S.A.R. of China
# 797 Hong Kong S.A.R. of China
# 798 Hong Kong S.A.R. of China
# 799 Hong Kong S.A.R. of China
# 800 Hong Kong S.A.R. of China
# 801 Hong Kong S.A.R. of China
# 802 Hong Kong S.A.R. of China
# 803 Hong Kong S.A.R. of China
# 804 Hong Kong S.A.R. of China
# 805 Hungary
# 806 Hungary
# 807 Hungary
# 808 Hungary
# 809 Hungary
# 810 Hungary
# 811 Hungary
# 812 Hungary
# 813 Hungary
# 814 Hungary
# 815 Hungary
# 816 Hungary
# 817 Hungary
# 818 Hungary
# 819 Hungary
# 820 Hungary
# 821 Iceland
# 822 Iceland
# 823 Iceland
# 824 Iceland
# 825 Iceland
# 826 Iceland
# 827 Iceland
# 828 Iceland
# 829 Iceland
# 830 Iceland
# 831 India
# 832 India
# 833 India
# 834 India
# 835 India
# 836 India
# 837 India
# 838 India
# 839 India
# 840 India
# 841 India
# 842 India
# 843 India
# 844 India
# 845 India
# 846 India
# 847 India
# 848 Indonesia
# 849 Indonesia
# 850 Indonesia
# 851 Indonesia
# 852 Indonesia
# 853 Indonesia
# 854 Indonesia
# 855 Indonesia
# 856 Indonesia
# 857 Indonesia
# 858 Indonesia
# 859 Indonesia
# 860 Indonesia
# 861 Indonesia
# 862 Indonesia
# 863 Indonesia
# 864 Indonesia
# 865 Iran
# 866 Iran
# 867 Iran
# 868 Iran
# 869 Iran
# 870 Iran
# 871 Iran
# 872 Iran
# 873 Iran
# 874 Iran
# 875 Iran
# 876 Iran
# 877 Iran
# 878 Iran
# 879 Iran
# 880 Iraq
# 881 Iraq
# 882 Iraq
# 883 Iraq
# 884 Iraq
# 885 Iraq
# 886 Iraq
# 887 Iraq
# 888 Iraq
# 889 Iraq
# 890 Iraq
# 891 Iraq
# 892 Iraq
# 893 Ireland
# 894 Ireland
# 895 Ireland
# 896 Ireland
# 897 Ireland
# 898 Ireland
# 899 Ireland
# 900 Ireland
# 901 Ireland
# 902 Ireland
# 903 Ireland
# 904 Ireland
# 905 Ireland
# 906 Ireland
# 907 Ireland
# 908 Ireland
# 909 Israel
# 910 Israel
# 911 Israel
# 912 Israel
# 913 Israel
# 914 Israel
# 915 Israel
# 916 Israel
# 917 Israel
# 918 Israel
# 919 Israel
# 920 Israel
# 921 Israel
# 922 Israel
# 923 Israel
# 924 Israel
# 925 Israel
# 926 Italy
# 927 Italy
# 928 Italy
# 929 Italy
# 930 Italy
# 931 Italy
# 932 Italy
# 933 Italy
# 934 Italy
# 935 Italy
# 936 Italy
# 937 Italy
# 938 Italy
# 939 Italy
# 940 Italy
# 941 Italy
# 942 Italy
# 943 Ivory Coast
# 944 Ivory Coast
# 945 Ivory Coast
# 946 Ivory Coast
# 947 Ivory Coast
# 948 Ivory Coast
# 949 Ivory Coast
# 950 Ivory Coast
# 951 Ivory Coast
# 952 Ivory Coast
# 953 Ivory Coast
# 954 Jamaica
# 955 Jamaica
# 956 Jamaica
# 957 Jamaica
# 958 Jamaica
# 959 Jamaica
# 960 Jamaica
# 961 Jamaica
# 962 Jamaica
# 963 Japan
# 964 Japan
# 965 Japan
# 966 Japan
# 967 Japan
# 968 Japan
# 969 Japan
# 970 Japan
# 971 Japan
# 972 Japan
# 973 Japan
# 974 Japan
# 975 Japan
# 976 Japan
# 977 Japan
# 978 Japan
# 979 Japan
# 980 Jordan
# 981 Jordan
# 982 Jordan
# 983 Jordan
# 984 Jordan
# 985 Jordan
# 986 Jordan
# 987 Jordan
# 988 Jordan
# 989 Jordan
# 990 Jordan
# 991 Jordan
# 992 Jordan
# 993 Jordan
# 994 Jordan
# 995 Jordan
# 996 Jordan
# 997 Kazakhstan
# 998 Kazakhstan
# 999 Kazakhstan
# 1000 Kazakhstan
# 1001 Kazakhstan
# 1002 Kazakhstan
# 1003 Kazakhstan
# 1004 Kazakhstan
# 1005 Kazakhstan
# 1006 Kazakhstan
# 1007 Kazakhstan
# 1008 Kazakhstan
# 1009 Kazakhstan
# 1010 Kazakhstan
# 1011 Kazakhstan
# 1012 Kazakhstan
# 1013 Kazakhstan
# 1014 Kenya
# 1015 Kenya
# 1016 Kenya
# 1017 Kenya
# 1018 Kenya
# 1019 Kenya
# 1020 Kenya
# 1021 Kenya
# 1022 Kenya
# 1023 Kenya
# 1024 Kenya
# 1025 Kenya
# 1026 Kenya
# 1027 Kenya
# 1028 Kenya
# 1029 Kenya
# 1030 Kenya
# 1031 Kosovo
# 1032 Kosovo
# 1033 Kosovo
# 1034 Kosovo
# 1035 Kosovo
# 1036 Kosovo
# 1037 Kosovo
# 1038 Kosovo
# 1039 Kosovo
# 1040 Kosovo
# 1041 Kosovo
# 1042 Kosovo
# 1043 Kosovo
# 1044 Kosovo
# 1045 Kosovo
# 1046 Kosovo
# 1047 Kuwait
# 1048 Kuwait
# 1049 Kuwait
# 1050 Kuwait
# 1051 Kuwait
# 1052 Kuwait
# 1053 Kuwait
# 1054 Kuwait
# 1055 Kuwait
# 1056 Kuwait
# 1057 Kuwait
# 1058 Kyrgyzstan
# 1059 Kyrgyzstan
# 1060 Kyrgyzstan
# 1061 Kyrgyzstan
# 1062 Kyrgyzstan
# 1063 Kyrgyzstan
# 1064 Kyrgyzstan
# 1065 Kyrgyzstan
# 1066 Kyrgyzstan
# 1067 Kyrgyzstan
# 1068 Kyrgyzstan
# 1069 Kyrgyzstan
# 1070 Kyrgyzstan
# 1071 Kyrgyzstan
# 1072 Kyrgyzstan
# 1073 Kyrgyzstan
# 1074 Kyrgyzstan
# 1075 Laos
# 1076 Laos
# 1077 Laos
# 1078 Laos
# 1079 Laos
# 1080 Laos
# 1081 Laos
# 1082 Laos
# 1083 Laos
# 1084 Laos
# 1085 Latvia
# 1086 Latvia
# 1087 Latvia
# 1088 Latvia
# 1089 Latvia
# 1090 Latvia
# 1091 Latvia
# 1092 Latvia
# 1093 Latvia
# 1094 Latvia
# 1095 Latvia
# 1096 Latvia
# 1097 Latvia
# 1098 Latvia
# 1099 Latvia
# 1100 Latvia
# 1101 Lebanon
# 1102 Lebanon
# 1103 Lebanon
# 1104 Lebanon
# 1105 Lebanon
# 1106 Lebanon
# 1107 Lebanon
# 1108 Lebanon
# 1109 Lebanon
# 1110 Lebanon
# 1111 Lebanon
# 1112 Lebanon
# 1113 Lebanon
# 1114 Lebanon
# 1115 Lebanon
# 1116 Lebanon
# 1117 Lebanon
# 1118 Lesotho
# 1119 Lesotho
# 1120 Lesotho
# 1121 Lesotho
# 1122 Liberia
# 1123 Liberia
# 1124 Liberia
# 1125 Liberia
# 1126 Liberia
# 1127 Liberia
# 1128 Liberia
# 1129 Liberia
# 1130 Liberia
# 1131 Liberia
# 1132 Libya
# 1133 Libya
# 1134 Libya
# 1135 Libya
# 1136 Libya
# 1137 Libya
# 1138 Lithuania
# 1139 Lithuania
# 1140 Lithuania
# 1141 Lithuania
# 1142 Lithuania
# 1143 Lithuania
# 1144 Lithuania
# 1145 Lithuania
# 1146 Lithuania
# 1147 Lithuania
# 1148 Lithuania
# 1149 Lithuania
# 1150 Lithuania
# 1151 Lithuania
# 1152 Lithuania
# 1153 Lithuania
# 1154 Lithuania
# 1155 Luxembourg
# 1156 Luxembourg
# 1157 Luxembourg
# 1158 Luxembourg
# 1159 Luxembourg
# 1160 Luxembourg
# 1161 Luxembourg
# 1162 Luxembourg
# 1163 Luxembourg
# 1164 Luxembourg
# 1165 Luxembourg
# 1166 Luxembourg
# 1167 Madagascar
# 1168 Madagascar
# 1169 Madagascar
# 1170 Madagascar
# 1171 Madagascar
# 1172 Madagascar
# 1173 Madagascar
# 1174 Madagascar
# 1175 Madagascar
# 1176 Madagascar
# 1177 Madagascar
# 1178 Madagascar
# 1179 Malawi
# 1180 Malawi
# 1181 Malawi
# 1182 Malawi
# 1183 Malawi
# 1184 Malawi
# 1185 Malawi
# 1186 Malawi
# 1187 Malawi
# 1188 Malawi
# 1189 Malawi
# 1190 Malawi
# 1191 Malawi
# 1192 Malawi
# 1193 Malaysia
# 1194 Malaysia
# 1195 Malaysia
# 1196 Malaysia
# 1197 Malaysia
# 1198 Malaysia
# 1199 Malaysia
# 1200 Malaysia
# 1201 Malaysia
# 1202 Malaysia
# 1203 Malaysia
# 1204 Malaysia
# 1205 Malaysia
# 1206 Malaysia
# 1207 Maldives
# 1208 Mali
# 1209 Mali
# 1210 Mali
# 1211 Mali
# 1212 Mali
# 1213 Mali
# 1214 Mali
# 1215 Mali
# 1216 Mali
# 1217 Mali
# 1218 Mali
# 1219 Mali
# 1220 Mali
# 1221 Mali
# 1222 Mali
# 1223 Mali
# 1224 Malta
# 1225 Malta
# 1226 Malta
# 1227 Malta
# 1228 Malta
# 1229 Malta
# 1230 Malta
# 1231 Malta
# 1232 Malta
# 1233 Malta
# 1234 Malta
# 1235 Malta
# 1236 Malta
# 1237 Malta
# 1238 Mauritania
# 1239 Mauritania
# 1240 Mauritania
# 1241 Mauritania
# 1242 Mauritania
# 1243 Mauritania
# 1244 Mauritania
# 1245 Mauritania
# 1246 Mauritania
# 1247 Mauritania
# 1248 Mauritania
# 1249 Mauritania
# 1250 Mauritania
# 1251 Mauritania
# 1252 Mauritius
# 1253 Mauritius
# 1254 Mauritius
# 1255 Mauritius
# 1256 Mauritius
# 1257 Mauritius
# 1258 Mauritius
# 1259 Mauritius
# 1260 Mauritius
# 1261 Mexico
# 1262 Mexico
# 1263 Mexico
# 1264 Mexico
# 1265 Mexico
# 1266 Mexico
# 1267 Mexico
# 1268 Mexico
# 1269 Mexico
# 1270 Mexico
# 1271 Mexico
# 1272 Mexico
# 1273 Mexico
# 1274 Mexico
# 1275 Mexico
# 1276 Mexico
# 1277 Mexico
# 1278 Moldova
# 1279 Moldova
# 1280 Moldova
# 1281 Moldova
# 1282 Moldova
# 1283 Moldova
# 1284 Moldova
# 1285 Moldova
# 1286 Moldova
# 1287 Moldova
# 1288 Moldova
# 1289 Moldova
# 1290 Moldova
# 1291 Moldova
# 1292 Moldova
# 1293 Moldova
# 1294 Moldova
# 1295 Mongolia
# 1296 Mongolia
# 1297 Mongolia
# 1298 Mongolia
# 1299 Mongolia
# 1300 Mongolia
# 1301 Mongolia
# 1302 Mongolia
# 1303 Mongolia
# 1304 Mongolia
# 1305 Mongolia
# 1306 Mongolia
# 1307 Mongolia
# 1308 Mongolia
# 1309 Mongolia
# 1310 Montenegro
# 1311 Montenegro
# 1312 Montenegro
# 1313 Montenegro
# 1314 Montenegro
# 1315 Montenegro
# 1316 Montenegro
# 1317 Montenegro
# 1318 Montenegro
# 1319 Montenegro
# 1320 Montenegro
# 1321 Montenegro
# 1322 Montenegro
# 1323 Morocco
# 1324 Morocco
# 1325 Morocco
# 1326 Morocco
# 1327 Morocco
# 1328 Morocco
# 1329 Morocco
# 1330 Morocco
# 1331 Morocco
# 1332 Morocco
# 1333 Morocco
# 1334 Morocco
# 1335 Mozambique
# 1336 Mozambique
# 1337 Mozambique
# 1338 Mozambique
# 1339 Mozambique
# 1340 Mozambique
# 1341 Mozambique
# 1342 Mozambique
# 1343 Mozambique
# 1344 Mozambique
# 1345 Myanmar
# 1346 Myanmar
# 1347 Myanmar
# 1348 Myanmar
# 1349 Myanmar
# 1350 Myanmar
# 1351 Myanmar
# 1352 Myanmar
# 1353 Myanmar
# 1354 Myanmar
# 1355 Namibia
# 1356 Namibia
# 1357 Namibia
# 1358 Namibia
# 1359 Namibia
# 1360 Namibia
# 1361 Namibia
# 1362 Namibia
# 1363 Nepal
# 1364 Nepal
# 1365 Nepal
# 1366 Nepal
# 1367 Nepal
# 1368 Nepal
# 1369 Nepal
# 1370 Nepal
# 1371 Nepal
# 1372 Nepal
# 1373 Nepal
# 1374 Nepal
# 1375 Nepal
# 1376 Nepal
# 1377 Nepal
# 1378 Nepal
# 1379 Nepal
# 1380 Netherlands
# 1381 Netherlands
# 1382 Netherlands
# 1383 Netherlands
# 1384 Netherlands
# 1385 Netherlands
# 1386 Netherlands
# 1387 Netherlands
# 1388 Netherlands
# 1389 Netherlands
# 1390 Netherlands
# 1391 Netherlands
# 1392 Netherlands
# 1393 Netherlands
# 1394 Netherlands
# 1395 Netherlands
# 1396 New Zealand
# 1397 New Zealand
# 1398 New Zealand
# 1399 New Zealand
# 1400 New Zealand
# 1401 New Zealand
# 1402 New Zealand
# 1403 New Zealand
# 1404 New Zealand
# 1405 New Zealand
# 1406 New Zealand
# 1407 New Zealand
# 1408 New Zealand
# 1409 New Zealand
# 1410 New Zealand
# 1411 New Zealand
# 1412 Nicaragua
# 1413 Nicaragua
# 1414 Nicaragua
# 1415 Nicaragua
# 1416 Nicaragua
# 1417 Nicaragua
# 1418 Nicaragua
# 1419 Nicaragua
# 1420 Nicaragua
# 1421 Nicaragua
# 1422 Nicaragua
# 1423 Nicaragua
# 1424 Nicaragua
# 1425 Nicaragua
# 1426 Nicaragua
# 1427 Nicaragua
# 1428 Nicaragua
# 1429 Niger
# 1430 Niger
# 1431 Niger
# 1432 Niger
# 1433 Niger
# 1434 Niger
# 1435 Niger
# 1436 Niger
# 1437 Niger
# 1438 Niger
# 1439 Niger
# 1440 Niger
# 1441 Niger
# 1442 Niger
# 1443 Niger
# 1444 Nigeria
# 1445 Nigeria
# 1446 Nigeria
# 1447 Nigeria
# 1448 Nigeria
# 1449 Nigeria
# 1450 Nigeria
# 1451 Nigeria
# 1452 Nigeria
# 1453 Nigeria
# 1454 Nigeria
# 1455 Nigeria
# 1456 Nigeria
# 1457 Nigeria
# 1458 North Macedonia
# 1459 North Macedonia
# 1460 North Macedonia
# 1461 North Macedonia
# 1462 North Macedonia
# 1463 North Macedonia
# 1464 North Macedonia
# 1465 North Macedonia
# 1466 North Macedonia
# 1467 North Macedonia
# 1468 North Macedonia
# 1469 North Macedonia
# 1470 North Macedonia
# 1471 North Macedonia
# 1472 North Macedonia
# 1473 Norway
# 1474 Norway
# 1475 Norway
# 1476 Norway
# 1477 Norway
# 1478 Norway
# 1479 Norway
# 1480 Norway
# 1481 Norway
# 1482 Norway
# 1483 Norway
# 1484 Norway
# 1485 Oman
# 1486 Pakistan
# 1487 Pakistan
# 1488 Pakistan
# 1489 Pakistan
# 1490 Pakistan
# 1491 Pakistan
# 1492 Pakistan
# 1493 Pakistan
# 1494 Pakistan
# 1495 Pakistan
# 1496 Pakistan
# 1497 Pakistan
# 1498 Pakistan
# 1499 Pakistan
# 1500 Pakistan
# 1501 Pakistan
# 1502 Panama
# 1503 Panama
# 1504 Panama
# 1505 Panama
# 1506 Panama
# 1507 Panama
# 1508 Panama
# 1509 Panama
# 1510 Panama
# 1511 Panama
# 1512 Panama
# 1513 Panama
# 1514 Panama
# 1515 Panama
# 1516 Panama
# 1517 Panama
# 1518 Paraguay
# 1519 Paraguay
# 1520 Paraguay
# 1521 Paraguay
# 1522 Paraguay
# 1523 Paraguay
# 1524 Paraguay
# 1525 Paraguay
# 1526 Paraguay
# 1527 Paraguay
# 1528 Paraguay
# 1529 Paraguay
# 1530 Paraguay
# 1531 Paraguay
# 1532 Paraguay
# 1533 Paraguay
# 1534 Peru
# 1535 Peru
# 1536 Peru
# 1537 Peru
# 1538 Peru
# 1539 Peru
# 1540 Peru
# 1541 Peru
# 1542 Peru
# 1543 Peru
# 1544 Peru
# 1545 Peru
# 1546 Peru
# 1547 Peru
# 1548 Peru
# 1549 Peru
# 1550 Peru
# 1551 Philippines
# 1552 Philippines
# 1553 Philippines
# 1554 Philippines
# 1555 Philippines
# 1556 Philippines
# 1557 Philippines
# 1558 Philippines
# 1559 Philippines
# 1560 Philippines
# 1561 Philippines
# 1562 Philippines
# 1563 Philippines
# 1564 Philippines
# 1565 Philippines
# 1566 Philippines
# 1567 Poland
# 1568 Poland
# 1569 Poland
# 1570 Poland
# 1571 Poland
# 1572 Poland
# 1573 Poland
# 1574 Poland
# 1575 Poland
# 1576 Poland
# 1577 Poland
# 1578 Poland
# 1579 Poland
# 1580 Poland
# 1581 Poland
# 1582 Poland
# 1583 Portugal
# 1584 Portugal
# 1585 Portugal
# 1586 Portugal
# 1587 Portugal
# 1588 Portugal
# 1589 Portugal
# 1590 Portugal
# 1591 Portugal
# 1592 Portugal
# 1593 Portugal
# 1594 Portugal
# 1595 Portugal
# 1596 Portugal
# 1597 Portugal
# 1598 Qatar
# 1599 Qatar
# 1600 Qatar
# 1601 Qatar
# 1602 Qatar
# 1603 Romania
# 1604 Romania
# 1605 Romania
# 1606 Romania
# 1607 Romania
# 1608 Romania
# 1609 Romania
# 1610 Romania
# 1611 Romania
# 1612 Romania
# 1613 Romania
# 1614 Romania
# 1615 Romania
# 1616 Romania
# 1617 Romania
# 1618 Romania
# 1619 Russia
# 1620 Russia
# 1621 Russia
# 1622 Russia
# 1623 Russia
# 1624 Russia
# 1625 Russia
# 1626 Russia
# 1627 Russia
# 1628 Russia
# 1629 Russia
# 1630 Russia
# 1631 Russia
# 1632 Russia
# 1633 Russia
# 1634 Russia
# 1635 Russia
# 1636 Rwanda
# 1637 Rwanda
# 1638 Rwanda
# 1639 Rwanda
# 1640 Rwanda
# 1641 Rwanda
# 1642 Rwanda
# 1643 Rwanda
# 1644 Rwanda
# 1645 Rwanda
# 1646 Rwanda
# 1647 Rwanda
# 1648 Saudi Arabia
# 1649 Saudi Arabia
# 1650 Saudi Arabia
# 1651 Saudi Arabia
# 1652 Saudi Arabia
# 1653 Saudi Arabia
# 1654 Saudi Arabia
# 1655 Saudi Arabia
# 1656 Saudi Arabia
# 1657 Saudi Arabia
# 1658 Saudi Arabia
# 1659 Saudi Arabia
# 1660 Saudi Arabia
# 1661 Saudi Arabia
# 1662 Saudi Arabia
# 1663 Saudi Arabia
# 1664 Saudi Arabia
# 1665 Senegal
# 1666 Senegal
# 1667 Senegal
# 1668 Senegal
# 1669 Senegal
# 1670 Senegal
# 1671 Senegal
# 1672 Senegal
# 1673 Senegal
# 1674 Senegal
# 1675 Senegal
# 1676 Senegal
# 1677 Senegal
# 1678 Senegal
# 1679 Senegal
# 1680 Senegal
# 1681 Senegal
# 1682 Serbia
# 1683 Serbia
# 1684 Serbia
# 1685 Serbia
# 1686 Serbia
# 1687 Serbia
# 1688 Serbia
# 1689 Serbia
# 1690 Serbia
# 1691 Serbia
# 1692 Serbia
# 1693 Serbia
# 1694 Serbia
# 1695 Serbia
# 1696 Sierra Leone
# 1697 Sierra Leone
# 1698 Sierra Leone
# 1699 Sierra Leone
# 1700 Sierra Leone
# 1701 Sierra Leone
# 1702 Sierra Leone
# 1703 Sierra Leone
# 1704 Sierra Leone
# 1705 Sierra Leone
# 1706 Sierra Leone
# 1707 Sierra Leone
# 1708 Sierra Leone
# 1709 Sierra Leone
# 1710 Singapore
# 1711 Singapore
# 1712 Singapore
# 1713 Singapore
# 1714 Singapore
# 1715 Singapore
# 1716 Singapore
# 1717 Singapore
# 1718 Singapore
# 1719 Singapore
# 1720 Singapore
# 1721 Singapore
# 1722 Singapore
# 1723 Singapore
# 1724 Slovakia
# 1725 Slovakia
# 1726 Slovakia
# 1727 Slovakia
# 1728 Slovakia
# 1729 Slovakia
# 1730 Slovakia
# 1731 Slovakia
# 1732 Slovakia
# 1733 Slovakia
# 1734 Slovakia
# 1735 Slovakia
# 1736 Slovakia
# 1737 Slovenia
# 1738 Slovenia
# 1739 Slovenia
# 1740 Slovenia
# 1741 Slovenia
# 1742 Slovenia
# 1743 Slovenia
# 1744 Slovenia
# 1745 Slovenia
# 1746 Slovenia
# 1747 Slovenia
# 1748 Slovenia
# 1749 Slovenia
# 1750 Slovenia
# 1751 Slovenia
# 1752 Somalia
# 1753 Somalia
# 1754 Somalia
# 1755 Somaliland region
# 1756 Somaliland region
# 1757 Somaliland region
# 1758 Somaliland region
# 1759 South Africa
# 1760 South Africa
# 1761 South Africa
# 1762 South Africa
# 1763 South Africa
# 1764 South Africa
# 1765 South Africa
# 1766 South Africa
# 1767 South Africa
# 1768 South Africa
# 1769 South Africa
# 1770 South Africa
# 1771 South Africa
# 1772 South Africa
# 1773 South Africa
# 1774 South Africa
# 1775 South Korea
# 1776 South Korea
# 1777 South Korea
# 1778 South Korea
# 1779 South Korea
# 1780 South Korea
# 1781 South Korea
# 1782 South Korea
# 1783 South Korea
# 1784 South Korea
# 1785 South Korea
# 1786 South Korea
# 1787 South Korea
# 1788 South Korea
# 1789 South Korea
# 1790 South Korea
# 1791 South Korea
# 1792 South Sudan
# 1793 South Sudan
# 1794 South Sudan
# 1795 South Sudan
# 1796 Spain
# 1797 Spain
# 1798 Spain
# 1799 Spain
# 1800 Spain
# 1801 Spain
# 1802 Spain
# 1803 Spain
# 1804 Spain
# 1805 Spain
# 1806 Spain
# 1807 Spain
# 1808 Spain
# 1809 Spain
# 1810 Spain
# 1811 Spain
# 1812 Spain
# 1813 Sri Lanka
# 1814 Sri Lanka
# 1815 Sri Lanka
# 1816 Sri Lanka
# 1817 Sri Lanka
# 1818 Sri Lanka
# 1819 Sri Lanka
# 1820 Sri Lanka
# 1821 Sri Lanka
# 1822 Sri Lanka
# 1823 Sri Lanka
# 1824 Sri Lanka
# 1825 Sri Lanka
# 1826 Sri Lanka
# 1827 Sri Lanka
# 1828 State of Palestine
# 1829 State of Palestine
# 1830 State of Palestine
# 1831 State of Palestine
# 1832 State of Palestine
# 1833 State of Palestine
# 1834 State of Palestine
# 1835 State of Palestine
# 1836 State of Palestine
# 1837 State of Palestine
# 1838 State of Palestine
# 1839 State of Palestine
# 1840 State of Palestine
# 1841 State of Palestine
# 1842 State of Palestine
# 1843 Sudan
# 1844 Sudan
# 1845 Sudan
# 1846 Sudan
# 1847 Sudan
# 1848 Suriname
# 1849 Sweden
# 1850 Sweden
# 1851 Sweden
# 1852 Sweden
# 1853 Sweden
# 1854 Sweden
# 1855 Sweden
# 1856 Sweden
# 1857 Sweden
# 1858 Sweden
# 1859 Sweden
# 1860 Sweden
# 1861 Sweden
# 1862 Sweden
# 1863 Sweden
# 1864 Sweden
# 1865 Sweden
# 1866 Switzerland
# 1867 Switzerland
# 1868 Switzerland
# 1869 Switzerland
# 1870 Switzerland
# 1871 Switzerland
# 1872 Switzerland
# 1873 Switzerland
# 1874 Switzerland
# 1875 Switzerland
# 1876 Switzerland
# 1877 Switzerland
# 1878 Syria
# 1879 Syria
# 1880 Syria
# 1881 Syria
# 1882 Syria
# 1883 Syria
# 1884 Syria
# 1885 Taiwan Province of China
# 1886 Taiwan Province of China
# 1887 Taiwan Province of China
# 1888 Taiwan Province of China
# 1889 Taiwan Province of China
# 1890 Taiwan Province of China
# 1891 Taiwan Province of China
# 1892 Taiwan Province of China
# 1893 Taiwan Province of China
# 1894 Taiwan Province of China
# 1895 Taiwan Province of China
# 1896 Taiwan Province of China
# 1897 Taiwan Province of China
# 1898 Taiwan Province of China
# 1899 Taiwan Province of China
# 1900 Tajikistan
# 1901 Tajikistan
# 1902 Tajikistan
# 1903 Tajikistan
# 1904 Tajikistan
# 1905 Tajikistan
# 1906 Tajikistan
# 1907 Tajikistan
# 1908 Tajikistan
# 1909 Tajikistan
# 1910 Tajikistan
# 1911 Tajikistan
# 1912 Tajikistan
# 1913 Tajikistan
# 1914 Tajikistan
# 1915 Tajikistan
# 1916 Tanzania
# 1917 Tanzania
# 1918 Tanzania
# 1919 Tanzania
# 1920 Tanzania
# 1921 Tanzania
# 1922 Tanzania
# 1923 Tanzania
# 1924 Tanzania
# 1925 Tanzania
# 1926 Tanzania
# 1927 Tanzania
# 1928 Tanzania
# 1929 Tanzania
# 1930 Tanzania
# 1931 Tanzania
# 1932 Tanzania
# 1933 Thailand
# 1934 Thailand
# 1935 Thailand
# 1936 Thailand
# 1937 Thailand
# 1938 Thailand
# 1939 Thailand
# 1940 Thailand
# 1941 Thailand
# 1942 Thailand
# 1943 Thailand
# 1944 Thailand
# 1945 Thailand
# 1946 Thailand
# 1947 Thailand
# 1948 Thailand
# 1949 Thailand
# 1950 Togo
# 1951 Togo
# 1952 Togo
# 1953 Togo
# 1954 Togo
# 1955 Togo
# 1956 Togo
# 1957 Togo
# 1958 Togo
# 1959 Togo
# 1960 Togo
# 1961 Trinidad and Tobago
# 1962 Trinidad and Tobago
# 1963 Trinidad and Tobago
# 1964 Trinidad and Tobago
# 1965 Trinidad and Tobago
# 1966 Tunisia
# 1967 Tunisia
# 1968 Tunisia
# 1969 Tunisia
# 1970 Tunisia
# 1971 Tunisia
# 1972 Tunisia
# 1973 Tunisia
# 1974 Tunisia
# 1975 Tunisia
# 1976 Tunisia
# 1977 Tunisia
# 1978 Tunisia
# 1979 Tunisia
# 1980 Turkiye
# 1981 Turkiye
# 1982 Turkiye
# 1983 Turkiye
# 1984 Turkiye
# 1985 Turkiye
# 1986 Turkiye
# 1987 Turkiye
# 1988 Turkiye
# 1989 Turkiye
# 1990 Turkiye
# 1991 Turkiye
# 1992 Turkiye
# 1993 Turkiye
# 1994 Turkiye
# 1995 Turkiye
# 1996 Turkmenistan
# 1997 Turkmenistan
# 1998 Turkmenistan
# 1999 Turkmenistan
# 2000 Turkmenistan
# 2001 Turkmenistan
# 2002 Turkmenistan
# 2003 Turkmenistan
# 2004 Turkmenistan
# 2005 Turkmenistan
# 2006 Uganda
# 2007 Uganda
# 2008 Uganda
# 2009 Uganda
# 2010 Uganda
# 2011 Uganda
# 2012 Uganda
# 2013 Uganda
# 2014 Uganda
# 2015 Uganda
# 2016 Uganda
# 2017 Uganda
# 2018 Uganda
# 2019 Uganda
# 2020 Uganda
# 2021 Uganda
# 2022 Ukraine
# 2023 Ukraine
# 2024 Ukraine
# 2025 Ukraine
# 2026 Ukraine
# 2027 Ukraine
# 2028 Ukraine
# 2029 Ukraine
# 2030 Ukraine
# 2031 Ukraine
# 2032 Ukraine
# 2033 Ukraine
# 2034 Ukraine
# 2035 Ukraine
# 2036 Ukraine
# 2037 Ukraine
# 2038 Ukraine
# 2039 United Arab Emirates
# 2040 United Arab Emirates
# 2041 United Arab Emirates
# 2042 United Arab Emirates
# 2043 United Arab Emirates
# 2044 United Arab Emirates
# 2045 United Arab Emirates
# 2046 United Arab Emirates
# 2047 United Arab Emirates
# 2048 United Arab Emirates
# 2049 United Arab Emirates
# 2050 United Arab Emirates
# 2051 United Arab Emirates
# 2052 United Arab Emirates
# 2053 United Arab Emirates
# 2054 United Kingdom
# 2055 United Kingdom
# 2056 United Kingdom
# 2057 United Kingdom
# 2058 United Kingdom
# 2059 United Kingdom
# 2060 United Kingdom
# 2061 United Kingdom
# 2062 United Kingdom
# 2063 United Kingdom
# 2064 United Kingdom
# 2065 United Kingdom
# 2066 United Kingdom
# 2067 United Kingdom
# 2068 United Kingdom
# 2069 United Kingdom
# 2070 United Kingdom
# 2071 United States
# 2072 United States
# 2073 United States
# 2074 United States
# 2075 United States
# 2076 United States
# 2077 United States
# 2078 United States
# 2079 United States
# 2080 United States
# 2081 United States
# 2082 United States
# 2083 United States
# 2084 United States
# 2085 United States
# 2086 United States
# 2087 United States
# 2088 Uruguay
# 2089 Uruguay
# 2090 Uruguay
# 2091 Uruguay
# 2092 Uruguay
# 2093 Uruguay
# 2094 Uruguay
# 2095 Uruguay
# 2096 Uruguay
# 2097 Uruguay
# 2098 Uruguay
# 2099 Uruguay
# 2100 Uruguay
# 2101 Uruguay
# 2102 Uruguay
# 2103 Uruguay
# 2104 Uruguay
# 2105 Uzbekistan
# 2106 Uzbekistan
# 2107 Uzbekistan
# 2108 Uzbekistan
# 2109 Uzbekistan
# 2110 Uzbekistan
# 2111 Uzbekistan
# 2112 Uzbekistan
# 2113 Uzbekistan
# 2114 Uzbekistan
# 2115 Uzbekistan
# 2116 Uzbekistan
# 2117 Uzbekistan
# 2118 Uzbekistan
# 2119 Uzbekistan
# 2120 Uzbekistan
# 2121 Venezuela
# 2122 Venezuela
# 2123 Venezuela
# 2124 Venezuela
# 2125 Venezuela
# 2126 Venezuela
# 2127 Venezuela
# 2128 Venezuela
# 2129 Venezuela
# 2130 Venezuela
# 2131 Venezuela
# 2132 Venezuela
# 2133 Venezuela
# 2134 Venezuela
# 2135 Venezuela
# 2136 Venezuela
# 2137 Venezuela
# 2138 Vietnam
# 2139 Vietnam
# 2140 Vietnam
# 2141 Vietnam
# 2142 Vietnam
# 2143 Vietnam
# 2144 Vietnam
# 2145 Vietnam
# 2146 Vietnam
# 2147 Vietnam
# 2148 Vietnam
# 2149 Vietnam
# 2150 Vietnam
# 2151 Vietnam
# 2152 Vietnam
# 2153 Vietnam
# 2154 Vietnam
# 2155 Yemen
# 2156 Yemen
# 2157 Yemen
# 2158 Yemen
# 2159 Yemen
# 2160 Yemen
# 2161 Yemen
# 2162 Yemen
# 2163 Yemen
# 2164 Yemen
# 2165 Yemen
# 2166 Yemen
# 2167 Zambia
# 2168 Zambia
# 2169 Zambia
# 2170 Zambia
# 2171 Zambia
# 2172 Zambia
# 2173 Zambia
# 2174 Zambia
# 2175 Zambia
# 2176 Zambia
# 2177 Zambia
# 2178 Zambia
# 2179 Zambia
# 2180 Zambia
# 2181 Zambia
# 2182 Zimbabwe
# 2183 Zimbabwe
# 2184 Zimbabwe
# 2185 Zimbabwe
# 2186 Zimbabwe
# 2187 Zimbabwe
# 2188 Zimbabwe
# 2189 Zimbabwe
# 2190 Zimbabwe
# 2191 Zimbabwe
# 2192 Zimbabwe
# 2193 Zimbabwe
# 2194 Zimbabwe
# 2195 Zimbabwe
# 2196 Zimbabwe
# 2197 Zimbabwe
# 2198 Zimbabwe

# %% [markdown]
# ``.iloc[]``
# - Prioritize speed.
# - Need to access elements by their positions within the DataFrame.
# - Want to perform vectorized operations or work with slices.
#
# ``.iterrows()``
# - Need both the index and row contents
# - Smaller DataFrames where performance difference is less significant.

# %% [markdown]
# ## 3.7 Boolean Indexing
# Now to the more fun part. If you looked carefully at the dataset that was displayed above, you probably saw that the datapoints are available for different years. What if you are interested only in data from a certain year? Or from a certain country? Or perhaps where a value in a certain column is greater than some predetermined value? You can use boolean indexing.
#
# Run the cell below to select rows where the year equals to 2022. Try to uncomment some other row to see what it does.

# %%
# df[df["year"] == 2022]
df[df["life_ladder"] > 5]  # Select rows where life_ladder > 5
# df[df["life_ladder"] > 11] # This one should return an empty dataframe
# Out:
#      country_name  year  life_ladder  log_gdp_per_capita  social_support  \
# 15        Albania  2009        5.485               9.241           0.833
# 16        Albania  2010        5.269               9.283           0.733
# 17        Albania  2011        5.867               9.311           0.759
# 18        Albania  2012        5.510               9.326           0.785
# 24        Albania  2018        5.004               9.497           0.684
# ...           ...   ...          ...                 ...             ...
# 2153      Vietnam  2021        5.540               9.271           0.799
# 2154      Vietnam  2022        6.267               9.333           0.879
# 2170       Zambia  2009        5.260               7.971           0.782
# 2172       Zambia  2012        5.013               8.094           0.780
# 2173       Zambia  2013        5.244               8.111           0.761
#
#       healthy_life_expectancy_at_birth  freedom_to_make_life_choices  \
# 15                              67.320                         0.525
# 16                              67.600                         0.569
# 17                              67.880                         0.487
# 18                              68.160                         0.602
# 24                              69.075                         0.824
# ...                                ...                           ...
# 2153                            65.500                         0.897
# 2154                            65.600                         0.975
# 2170                            48.740                         0.696
# 2172                            50.720                         0.788
# 2173                            51.380                         0.770
#
#       generosity  perceptions_of_corruption  positive_affect  negative_affect
# 15        -0.159                      0.864            0.564            0.279
# 16        -0.174                      0.726            0.576            0.300
# 17        -0.206                      0.877            0.566            0.257
# 18        -0.170                      0.848            0.553            0.271
# 24         0.007                      0.899            0.592            0.319
# ...          ...                        ...              ...              ...
# 2153       0.107                      0.798            0.651            0.280
# 2154      -0.179                      0.703            0.774            0.108
# 2170      -0.097                      0.917            0.693            0.123
# 2172       0.007                      0.806            0.676            0.250
# 2173      -0.105                      0.732            0.727            0.308
#
# [1410 rows x 11 columns]

# %% [markdown]
# Note that now that you selected only the certain rows, the index column does not make much sense anymore because you have a lot of gaps. While this is not a problem, in some cases you might want the index to correspond to the actual row number. To achieve this you can use `reset_inex()`. In other cases you might want to keep the index as it is to more easily refer back to the original dataframe. It all depends on the context of your project. Run the cell below to reset the index and take a look at the output.

# %%
new_df = df[df["year"] == 2022]
new_df = new_df.reset_index(drop=True)
new_df
# Out:
#     country_name  year  life_ladder  log_gdp_per_capita  social_support  \
# 0    Afghanistan  2022        1.281                 NaN           0.228
# 1        Albania  2022        5.212               9.626           0.724
# 2      Argentina  2022        6.261              10.011           0.893
# 3        Armenia  2022        5.382               9.668           0.811
# 4      Australia  2022        7.035              10.854           0.942
# ..           ...   ...          ...                 ...             ...
# 109      Uruguay  2022        6.671              10.084           0.905
# 110   Uzbekistan  2022        6.016               8.990           0.879
# 111    Venezuela  2022        5.949                 NaN           0.899
# 112      Vietnam  2022        6.267               9.333           0.879
# 113     Zimbabwe  2022        3.296               7.670           0.666
#
#      healthy_life_expectancy_at_birth  freedom_to_make_life_choices  \
# 0                              54.875                         0.368
# 1                              69.175                         0.802
# 2                              67.250                         0.825
# 3                              67.925                         0.790
# 4                              71.125                         0.854
# ..                                ...                           ...
# 109                            67.500                         0.878
# 110                            65.600                         0.959
# 111                            63.875                         0.770
# 112                            65.600                         0.975
# 113                            54.525                         0.652
#
#      generosity  perceptions_of_corruption  positive_affect  negative_affect
# 0           NaN                      0.733            0.206            0.576
# 1        -0.066                      0.846            0.547            0.255
# 2        -0.128                      0.810            0.724            0.284
# 3        -0.154                      0.705            0.531            0.549
# 4         0.153                      0.545            0.711            0.244
# ..          ...                        ...              ...              ...
# 109      -0.052                      0.631            0.775            0.267
# 110       0.309                      0.616            0.741            0.225
# 111         NaN                      0.798            0.754            0.292
# 112      -0.179                      0.703            0.774            0.108
# 113      -0.070                      0.753            0.641            0.191
#
# [114 rows x 11 columns]

# %% [markdown]
# # 4. Summary Statistics
# Later in this course you will learn about summary statistics. For now, this is just to show you that Pandas allows for a very simple way to calculate all sorts of statistics using `describe()`. Run the cell below to see a quick statistical summary of your data. It doesn't matter if you don't know what each row means, you will learn all about it in the coming weeks.

# %%
df.describe()
# Out:
#               year  life_ladder  log_gdp_per_capita  social_support  \
# count  2199.000000  2199.000000         2179.000000     2186.000000
# mean   2014.161437     5.479227            9.389760        0.810681
# std       4.718736     1.125527            1.153402        0.120953
# min    2005.000000     1.281000            5.527000        0.228000
# 25%    2010.000000     4.647000            8.500000        0.747000
# 50%    2014.000000     5.432000            9.499000        0.836000
# 75%    2018.000000     6.309500           10.373500        0.905000
# max    2022.000000     8.019000           11.664000        0.987000
#
#        healthy_life_expectancy_at_birth  freedom_to_make_life_choices  \
# count                       2145.000000                   2166.000000
# mean                          63.294582                      0.747847
# std                            6.901104                      0.140137
# min                            6.720000                      0.258000
# 25%                           59.120000                      0.656250
# 50%                           65.050000                      0.770000
# 75%                           68.500000                      0.859000
# max                           74.475000                      0.985000
#
#         generosity  perceptions_of_corruption  positive_affect  \
# count  2126.000000                2083.000000      2175.000000
# mean      0.000091                   0.745208         0.652148
# std       0.161079                   0.185835         0.105913
# min      -0.338000                   0.035000         0.179000
# 25%      -0.112000                   0.688000         0.572000
# 50%      -0.023000                   0.800000         0.663000
# 75%       0.092000                   0.869000         0.738000
# max       0.703000                   0.983000         0.884000
#
#        negative_affect
# count      2183.000000
# mean          0.271493
# std           0.086872
# min           0.083000
# 25%           0.208000
# 50%           0.261000
# 75%           0.323000
# max           0.705000

# %% [markdown]
# Not all of the summary statistics always make sense. In your case, for example, you are looking at the summary statistics across various columns. But are you sure you know what the final numbers actually mean? You have data for many different countries, but are you sure that you have the same amount of datapoints for each country or for each year? Also the countries can have vastly different populations, is it fair to just average the numbers out?
#
# # 5. Plotting
# If you want to plot the data, you can use `DataFrame.plot()`. By default it uses the index as the x axis and plots all the numeric columns as y axes. Run the cell below to see the output for your dataframe.

# %%
# If the plot doesn’t render, first try re-running this cell. If that doesn’t work,
# you can restart the kernel (from the Kernel menu above) and try running the notebook again
df.plot()
# Out:
# <Axes: >

# %% [markdown]
# As you can see, in this case the plot is not very useful. The index does not have any specific meaning, and the values of various columns differ greatly (years are all around 2000, but the values in the other columns are much lower) and thus you cannot see much in the plot. Try setting some parameters of the `.plot()` method to see what it allows you to do. You can find the documentation [here](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.plot.html).
#
# Run the cell below to see a scatter plot with specifically chosen x and y variables. On the x axis there is logarithm of the GDP (measuring the wealth) while on the y axis there is the life ladder. This column contains values which are an estimate of self-assessed life quality on a scale of 1 to 10 as given by a survey among the people.

# %%
df.plot(kind="scatter", x="log_gdp_per_capita", y="life_ladder")
# Out:
# <Axes: xlabel='log_gdp_per_capita', ylabel='life_ladder'>

# %% [markdown]
# You can see that there is some sort of trend between the wealth of the country and the happiness of the population and you can say that it looks like that wealthier people are to some extent happier. In week three, you will explore this kind of relationship further.
#
# Sometimes it is very insightful to separate the points by colors to highlight different characteristics or some points you are most interested in. Take a look at the example below

# %%
# Create a dictionary to map the country names to colors
cmap = {"Brazil": "Green", "Slovenia": "Orange", "India": "purple"}

df.plot(
    kind="scatter",
    x="log_gdp_per_capita",
    y="life_ladder",
    c=[cmap.get(c, "yellow") for c in df.country_name],  # Set the colors
    s=2,  # Set the size of the points
)
# Out:
# <Axes: xlabel='log_gdp_per_capita', ylabel='life_ladder'>

# %% [markdown]
# You can see that even though in general higher GDP means higher value on the life ladder, this is not an universal truth. Comparing Slovenia (orange) with Brazil (green), you can see that people in Brazil earn less, but are on average happier than Slovenians through the years.
#
# Another very useful task you can do with plots is to visulize the distribution of your data. You will learn how to do this in more detail later, but for example you can easily plot a histogram using Pandas. Ise `DataFrame.hist()` on the dataframe you want to plot. Note that if you have many columns in the dataframe, this command will plot a histogram for each of the columns. You can select a single column from the dataframe if you only want to plot that one.

# %%
df.hist("life_ladder")
# Out:
# array([[<Axes: title={'center': 'life_ladder'}>]], dtype=object)

# %% [markdown]
# What you see in this histogram is a distribution of values in the "life_ladder" column. What do you think about this distribution on the first glance? Are the people generally happy about their quality of life? Note that to answer this question properly, you need to dig a bit deeper into the data: understand where each value comes from, as the values are not single datapoints (single answers by people), but already aggregated values across countries and at various points in time.
#
# You can use other external libraries to easily produce various advanced plots. One of such libraries is [Seaborn](https://seaborn.pydata.org/). You have already imported it at the beginning of this lab using `import seaborn as sns`. Run the cell below to see one of the many simple and efficient plotting possibilities (you will use this one later on in the other notebooks as well). Since the dataset has many columns it might take a few seconds to run.

# %%
# If the plot doesn’t render, first try re-running this cell. If that doesn’t work,
# you can restart the kernel (from the Kernel menu above) and try running the notebook again
sns.pairplot(df)
# Out:
# c:\Users\Chris\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\Chris\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\Chris\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\Chris\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\Chris\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\Chris\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\Chris\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\Chris\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\Chris\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\Chris\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# With this kind of plot, you can see pairwise scatter plots for each pair of columns. On the diagonal (where both columns are the same), you don't have a scatter plot (which would only show a line), but a histogram showing the distribution of datapoints.
#
# You can see that both the scatter plots and histograms have very different shapes across columns. Think about various insights you could get from this kind of visualization.

# %% [markdown]
# # 6. Operations on Columns
# Sometimes the values in the columns are not giving you the information that you need, but there is a way to calculate that information from the values you have.
#
# For example you can create a new column, which is a sum of two columns.

# %%
# Create a new column which is the sum of the year and the value on the life ladder.
df["this_column_makes_no_sense"] = df["year"] + df["life_ladder"]
# Create a new column which is the difference of two columns.
df["net_affect_difference"] = df["positive_affect"] - df["negative_affect"]

df.head()
# Out:
#   country_name  year  life_ladder  log_gdp_per_capita  social_support  \
# 0  Afghanistan  2008        3.724               7.350           0.451
# 1  Afghanistan  2009        4.402               7.509           0.552
# 2  Afghanistan  2010        4.758               7.614           0.539
# 3  Afghanistan  2011        3.832               7.581           0.521
# 4  Afghanistan  2012        3.783               7.661           0.521
#
#    healthy_life_expectancy_at_birth  freedom_to_make_life_choices  generosity  \
# 0                              50.5                         0.718       0.168
# 1                              50.8                         0.679       0.191
# 2                              51.1                         0.600       0.121
# 3                              51.4                         0.496       0.164
# 4                              51.7                         0.531       0.238
#
#    perceptions_of_corruption  positive_affect  negative_affect  \
# 0                      0.882            0.414            0.258
# 1                      0.850            0.481            0.237
# 2                      0.707            0.517            0.275
# 3                      0.731            0.480            0.267
# 4                      0.776            0.614            0.268
#
#    this_column_makes_no_sense  net_affect_difference
# 0                    2011.724                  0.156
# 1                    2013.402                  0.244
# 2                    2014.758                  0.242
# 3                    2014.832                  0.213
# 4                    2015.783                  0.346

# %% [markdown]
# Above you can see your dataframe with both new columns. The first one doesn't make much sense, it's just adding the year to the life ladder. The second one, however, find the net difference between positive and negative affect. Perhaps there's an interesting set of patterns between this new column and other columns that you'd now be able to explore. What other columns might you want to calculate? In general, the ability to create new columns using operations on existing columns can be a powerful tool.
#
# If you want to perform some more advanced operations on columns, you can use `DataFrame.apply()`, with which you can apply practically any function to a column. Below you can see how to use the `DataFrame.apply()` in various ways. Try to edit `my_function` to perform an operation of your choice.

# %%
# Using df.apply() with a lambda function
# Rescale the life_ladder column to values between 0 and 1 and save it to a new column
df["life_ladder_rescaled"] = df["life_ladder"].apply(lambda x: x / 10)


# Using df.apply() with your own function
# First define a function. The function can do whatever you want. This example will double the column's values
def my_function(x):
    # do stuff to x
    y = x * 2
    return y


# Apply the function.
df["my_function"] = df["life_ladder"].apply(my_function)

# Show the new dataframe
df.head()
# Out:
#   country_name  year  life_ladder  log_gdp_per_capita  social_support  \
# 0  Afghanistan  2008        3.724               7.350           0.451
# 1  Afghanistan  2009        4.402               7.509           0.552
# 2  Afghanistan  2010        4.758               7.614           0.539
# 3  Afghanistan  2011        3.832               7.581           0.521
# 4  Afghanistan  2012        3.783               7.661           0.521
#
#    healthy_life_expectancy_at_birth  freedom_to_make_life_choices  generosity  \
# 0                              50.5                         0.718       0.168
# 1                              50.8                         0.679       0.191
# 2                              51.1                         0.600       0.121
# 3                              51.4                         0.496       0.164
# 4                              51.7                         0.531       0.238
#
#    perceptions_of_corruption  positive_affect  negative_affect  \
# 0                      0.882            0.414            0.258
# 1                      0.850            0.481            0.237
# 2                      0.707            0.517            0.275
# 3                      0.731            0.480            0.267
# 4                      0.776            0.614            0.268
#
#    this_column_makes_no_sense  net_affect_difference  life_ladder_rescaled  \
# 0                    2011.724                  0.156                0.3724
# 1                    2013.402                  0.244                0.4402
# 2                    2014.758                  0.242                0.4758
# 3                    2014.832                  0.213                0.3832
# 4                    2015.783                  0.346                0.3783
#
#    my_function
# 0        7.448
# 1        8.804
# 2        9.516
# 3        7.664
# 4        7.566

# %% [markdown]
# **Congratulations on finishing this lab.** If you understand the code above, you are well suited to start working on this week's programming assignment and other labs and assignments throughout the course which use Pandas. If you need a refresher on Pandas in other Exploratory Data Analysis labs, come back to this one and review the skills taught here.
